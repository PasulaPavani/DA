# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# imported required libraries to read csv file

# %%
data=pd.read_csv(r"C:\Users\LENOVO\Documents\today\tips.csv")

# %% [markdown]
# provided the path to read csv file and assigned to "data"

# %%
data.shape
# Out:
# (244, 7)

# %% [markdown]
# In csv file we have 244 data points and 7 columns or attributes

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# The dataset which we have imported is displayed above with columns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# imported libraries that are used to plot and analyze the data with some variable name like "plt" ,"sns"

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# info() gives the whole information about the data set
# We have 244 data points ranging from 0 to 243 , tottal number of columns we have are 7
# We are provided with the data like the datatype in each column and count of columns of same data type

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# describe gives the descriptive statistics of the dataset having column datatype as int or float
# Count of [total_bill = 244,tip=244,size=244]
# mean of total_bill is
# mean of tip is
# mean of size is
#
# std=standard deviation
# std of total_bill is 8.902412
# std of tip is 1.383638
# std of size is 0.951100
#
# Total_bill is having the more standard deviation
#
# Minimum Total_bill paid is is 3.07
# Minimum tip given is 1.00
# Minimum size of attendees is 1
#
# Maximum total_bill paid is 50.8
# Maximum tip paid is 10.00
# Maximum size of attendees is 6.00

# %%
data.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# The columns or column names we have in our data are 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'

# %%
print(data.sex.unique())
print(data.sex.value_counts())
# Out:
# ['Female' 'Male']
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# From the given dataset
# 157 males went to restuarant and 87 females

# %%
plt.subplot(221)
sns.countplot(data=data,x=data["sex"])
plt.subplot(222)
data.sex.value_counts().plot(kind="pie",autopct="%.2f%%",title="Percentages of male and female had food in restuarant")

plt.tight_layout()
plt.show()

# %% [markdown]
# Out of total customers , 35.66 percent were Female and 64.34 percent were Male
# Males prefer to have food in restuarants more than females.

# %%
print(data.smoker.unique())
print(data.smoker.value_counts())
# Out:
# ['No' 'Yes']
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
plt.subplot(221)
sns.countplot(data=data,x=data["smoker"])
plt.subplot(222)

data.smoker.value_counts().plot(kind="pie",autopct="%.2f%%",title="Percentage of Smokers and non Smokers in the restuarant")
plt.tight_layout()
plt.show()

# %% [markdown]
# From the dataset
# there are 151 smokers and 93 are non-smokers
# Out of total customers , 61.89 percent were Non-smokers and 38.11 percent were smokers

# %%
print(data.time.unique())
print(data.time.value_counts())
# Out:
# ['Dinner' 'Lunch']
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %% [markdown]
# From the dataset
# 176 members came to restuarant for Dinner and 68 members for lunch which shows that the max people are interested to have dinner in restuarants

# %%
plt.subplot(221)
sns.countplot(data=data,x=data["time"])
plt.subplot(222)

data.time.value_counts().plot(kind="pie",autopct="%.2f%%",title="Percentage of customers had dinner , lunch")
plt.tight_layout()
plt.show()

# %% [markdown]
# From the dataset
# 176 members came to restuarant for Dinner and 68 members for lunch which shows that the max people are interested to have dinner in restuarants
# Out of total customers, 72.13 percent had dinner and 27.87 percent had lunch

# %%
print(data.day.unique())
print(data.day.value_counts())
# Out:
# ['Sun' 'Sat' 'Thur' 'Fri']
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
plt.subplot(221)
sns.countplot(data=data,x=data["day"])
plt.subplot(222)
data.day.value_counts().plot(kind="pie",autopct="%.2f%%",title ="Percentage of customers visited restuarant in weekdays")
plt.tight_layout()
plt.show()

# %% [markdown]
# Most people are likely to have food in restuarants on saturdays and next on sundays and less likely on Fridays

# %%
#data["size"]=data["size"].astype(str)
#print(data.size.unique())
#print(data.size.value_counts())

# %%
sns.histplot(data=data,x=data["tip"],y="total_bill",hue="sex")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
plt.subplot(221)
plt.hist(data["total_bill"])
plt.xlabel("bill_length")
plt.ylabel("no. of members")

plt.subplot(222)
sns.kdeplot(data=data,x="total_bill",hue="sex")
plt.tight_layout()

# %% [markdown]
# The maximum total_bill spent by males lies in between 11 and 25 ,by female lies in between 11 and 19

# %% [markdown]
# More number of customers paid total_bill between 10.3 and 23

# %%
plt.subplot(221)
plt.hist(data["tip"])
plt.xlabel("tip_length")
plt.ylabel("no. of members")
plt.subplot(222)
sns.kdeplot(data=data,x="tip",hue="sex")
plt.tight_layout()

# %% [markdown]
# More number of customers gave tip in between 1.3 and 4

# %%
sns.FacetGrid(data,hue="smoker").map(sns.kdeplot,"tip").add_legend()

# %% [markdown]
# tips given by smokers and non-smokers are almost equal and most tips were ranging from 1.5 to 4.85

# %%
sns.FacetGrid(data,hue="size").map(sns.kdeplot,"total_bill").add_legend()

# %%
sns.FacetGrid(data,hue="size").map(sns.kdeplot,"tip").add_legend()

# %%
sns.barplot(data=data,x="sex",y="total_bill",hue="size")
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# male with size of 6 paid the highest total_bill where as the female with size 1 has paid less total_bill where the remaining males and females of sizzes 2,3,4,5 spent in between 10 and 30

# %%
sns.barplot(data=data,x="sex",y="tip",hue="size")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# male with size of 6 paid the highest total_bill where as the female with size 1 has paid less tip where the remaining males and females of sizzes 2,3,4,5 spent in between 1.4 and 5

# %%
d1=pd.pivot_table(data,index="sex",columns="smoker",values=["total_bill"])

# %%
d1
# Out:
#        total_bill
# smoker         No        Yes
# sex
# Female  18.105185  17.977879
# Male    19.791237  22.284500

# %%
d=d1.loc[d1.index,:].plot(kind="bar",title="The average of males and females who smoke and who doesn't spent in restaurant")
d.title
d.set_ylabel("Average of total bill")
# Out:
# Text(0, 0.5, 'Average of total bill')

# %% [markdown]
#  18.105185 was the average total_bill spent by female non-smokers,
#  17.977879 was the average total_bill spent by female smokers,
#  22.284500 was the average total_bill spent by male smokers which is highest average among all,
#  19.791237 was the average total_bill spent by female smokers.

# %%
d2=pd.pivot_table(data,index="sex",columns="smoker",values=["total_bill","tip"])

# %%
d2
# Out:
#              tip           total_bill
# smoker        No       Yes         No        Yes
# sex
# Female  2.773519  2.931515  18.105185  17.977879
# Male    3.113402  3.051167  19.791237  22.284500

# %%
d22=d2.loc[d2.index,:].plot(kind="bar",title="The average of males and females who smoke and who doesn't spent in restuarant")
d22.title
d22.set_ylabel("average values of total_bill and tips")
# Out:
# Text(0, 0.5, 'average values of total_bill and tips')

# %% [markdown]
#  2.773519 was the average tip spent by female non-smokers,
#  2.931515 was the average tip spent by female smokers,
#  3.051167 was the average tip spent by male smokers which is highest average among all,
#  3.113402 was the average tip spent by female smokers.

# %%
d3=pd.pivot_table(data,index="sex",columns="smoker",values=["total_bill","tip"],margins=True,aggfunc="sum")

# %%
d3
# Out:
#            tip                 total_bill
# smoker      No     Yes     All         No      Yes      All
# sex
# Female  149.77   96.74  246.51     977.68   593.27  1570.95
# Male    302.00  183.07  485.07    1919.75  1337.07  3256.82
# All     451.77  279.81  731.58    2897.43  1930.34  4827.77

# %%
d33=d3.loc[d3.index,:].plot(kind="bar",title="The average of males and females who smoke and who doesn't spent in restuarant")
d33.title
d33.set_ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
# 4827.77 is the total_bill spent by both males,females,smokers,non_smokers
# 731.58   is the tip spent by both male and female smokers and non_smokers
#  1570.95 is the total_bill spent by females,smokers and non_smokers,
# 3256.82    is the total_bill spent by both male smokers and non_smokers,
#  279.81  is the total_bill spent by both male and female smokers,
#   2897.43	 is the total_bill spent by both male and female non_smokers,
 #  246.5   is the tip spent by females,smokers and non_smokers,
#  485.07    is the tip spent by both male smokers and non_smokers,
# 1930.34   is the tip spent by both male and female smokers,
 #  451.7  is the tip spent by both male and female non_smokers,

# %%
d4=pd.pivot_table(data,index="sex",columns="time",values=["total_bill","tip"],margins=True)

# %%
d4
# Out:
#              tip                     total_bill
# time      Dinner     Lunch       All     Dinner      Lunch        All
# sex
# Female  3.002115  2.582857  2.833448  19.213077  16.339143  18.056897
# Male    3.144839  2.882121  3.089618  21.461452  18.048485  20.744076
# All     3.102670  2.728088  2.998279  20.797159  17.168676  19.785943

# %%
d44=d4.loc[d4.index,:].plot(kind="bar",title="The average of males and females spent during lunch and dinner in restuarant")
d44.title
d44.set_ylabel("average of total_bill")
# Out:
# Text(0, 0.5, 'average of total_bill')

# %%
d5=pd.pivot_table(data,index="sex",columns="size",values=["total_bill","tip"],margins=True)

# %%
d5
# Out:
#              tip                                                        \
# size           1         2         3         4      5      6       All
# sex
# Female  1.276667  2.528448  3.250000  4.021111  5.140  4.600  2.833448
# Male    1.920000  2.614184  3.476667  4.172143  3.750  5.850  3.089618
# All     1.437500  2.582308  3.393158  4.135405  4.028  5.225  2.998279
#
#        total_bill
# size            1          2          3          4        5       6        All
# sex
# Female   6.796667  15.339483  21.547143  30.278889  29.8500  28.425  18.056897
# Male     8.580000  17.104082  24.287083  28.078214  30.1225  41.235  20.744076
# All      7.242500  16.448013  23.277632  28.613514  30.0680  34.830  19.785943

# %%
d55=d5.loc[d5.index,:].plot(kind="bar",title="The average  of tips and total_bill  of males and females of different sizes spent in restuarant")
d55.title
d55.set_ylabel("Average")
# Out:
# Text(0, 0.5, 'Average')

# %%
d7=pd.pivot_table(data,index="sex",columns="size",values="smoker",aggfunc="count")

# %%
d7
# Out:
# size    1   2   3   4  5  6
# sex
# Female  3  58  14   9  1  2
# Male    1  98  24  28  4  2

# %%
d77=d7.loc[d7.index,:].plot(kind="bar",title="The number of males and females of size are smokers or non_smokers in restuarant")
d77.title
d77.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #The highest size was of 6 of both genders  and the lowest size was of 1 of gender male
# #The count was highest for size 2 of gender "male"
